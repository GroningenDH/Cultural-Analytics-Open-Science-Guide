# %% [markdown]
# # APIs — Workbook

# %% [markdown]
# In this notebook, we will explore how to make simple API requests.

# %%
import requests
import pandas as pd
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 100

# %% [markdown]
# ## Open Brewery Database

# %% [markdown]
# https://api.openbrewerydb.org

# %% [markdown]
# Open Brewery Database API Endpoints:
#    - List Breweries
#    - Get Brewery
#    - Search Breweries
#    - Autocomplete

# %% [markdown]
# ## List Breweries

# %% [markdown]
# https://api.openbrewerydb.org/breweries

# %%
response = requests.get(f"https://api.openbrewerydb.org/breweries")

# %%
response.json()
# Out:
# [{'id': '10-56-brewing-company-knox',
#   'name': '10-56 Brewing Company',
#   'brewery_type': 'micro',
#   'street': '400 Brown Cir',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Knox',
#   'state': 'Indiana',
#   'county_province': None,
#   'postal_code': '46534',
#   'country': 'United States',
#   'longitude': '-86.627954',
#   'latitude': '41.289715',
#   'phone': '6308165790',
#   'website_url': None,
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10-barrel-brewing-co-bend-1',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'street': '62970 18th St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state': 'Oregon',
#   'county_province': None,
#   'postal_code': '97701-9847',
#   'country': 'United States',
#   'longitude': '-121.28170597038259',
#   'latitude': '44.08683530625218',
#   'phone': '5415851007',
#   'website_url': 'http://www.10barrel.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10-barrel-brewing-co-bend-2',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'street': '1135 NW Galveston Ave Ste B',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state': 'Oregon',
#   'county_province': None,
#   'postal_code': '97703-2465',
#   'country': 'United States',
#   'longitude': '-121.32880209261799',
#   'latitude': '44.057564901366796',
#   'phone': '5415851007',
#   'website_url': None,
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10-barrel-brewing-co-bend-pub-bend',
#   'name': '10 Barrel Brewing Co - Bend Pub',
#   'brewery_type': 'large',
#   'street': '62950 NE 18th St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state': 'Oregon',
#   'county_province': None,
#   'postal_code': '97701',
#   'country': 'United States',
#   'longitude': '-121.2809536',
#   'latitude': '44.0912109',
#   'phone': '5415851007',
#   'website_url': None,
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10-barrel-brewing-co-boise-boise',
#   'name': '10 Barrel Brewing Co - Boise',
#   'brewery_type': 'large',
#   'street': '826 W Bannock St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Boise',
#   'state': 'Idaho',
#   'county_province': None,
#   'postal_code': '83702-5857',
#   'country': 'United States',
#   'longitude': '-116.202929',
#   'latitude': '43.618516',
#   'phone': '2083445870',
#   'website_url': 'http://www.10barrel.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10-barrel-brewing-co-denver-denver',
#   'name': '10 Barrel Brewing Co - Denver',
#   'brewery_type': 'large',
#   'street': '2620 Walnut St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Denver',
#   'state': 'Colorado',
#   'county_province': None,
#   'postal_code': '80205-2231',
#   'country': 'United States',
#   'longitude': '-104.9853655',
#   'latitude': '39.7592508',
#   'phone': '7205738992',
#   'website_url': None,
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10-barrel-brewing-co-portland',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'street': '1411 NW Flanders St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Portland',
#   'state': 'Oregon',
#   'county_province': None,
#   'postal_code': '97209-2620',
#   'country': 'United States',
#   'longitude': '-122.6855056',
#   'latitude': '45.5259786',
#   'phone': '5032241700',
#   'website_url': 'http://www.10barrel.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10-barrel-brewing-co-san-diego',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'street': '1501 E St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'San Diego',
#   'state': 'California',
#   'county_province': None,
#   'postal_code': '92101-6618',
#   'country': 'United States',
#   'longitude': '-117.129593',
#   'latitude': '32.714813',
#   'phone': '6195782311',
#   'website_url': 'http://10barrel.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10-torr-distilling-and-brewing-reno',
#   'name': '10 Torr Distilling and Brewing',
#   'brewery_type': 'micro',
#   'street': '490 Mill St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Reno',
#   'state': 'Nevada',
#   'county_province': None,
#   'postal_code': '89502',
#   'country': 'United States',
#   'longitude': '-119.7732015',
#   'latitude': '39.5171702',
#   'phone': '7755307014',
#   'website_url': 'http://www.10torr.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '101-brewery-quilcene',
#   'name': '101 Brewery',
#   'brewery_type': 'brewpub',
#   'street': '294793 US Highway 101',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Quilcene',
#   'state': 'Washington',
#   'county_province': None,
#   'postal_code': '98376-9000',
#   'country': 'United States',
#   'longitude': '-122.87558226136872',
#   'latitude': '47.823475773720666',
#   'phone': '3607656485',
#   'website_url': 'http://www.101brewery.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '101-north-brewing-company-petaluma',
#   'name': '101 North Brewing Company',
#   'brewery_type': 'closed',
#   'street': '1304 Scott St Ste D',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Petaluma',
#   'state': 'California',
#   'county_province': None,
#   'postal_code': '94954-7100',
#   'country': 'United States',
#   'longitude': '-122.66505504468803',
#   'latitude': '38.270293813150886',
#   'phone': '7077534934',
#   'website_url': 'http://www.101northbeer.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '105-west-brewing-co-castle-rock',
#   'name': '105 West Brewing Co',
#   'brewery_type': 'micro',
#   'street': '1043 Park St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Castle Rock',
#   'state': 'Colorado',
#   'county_province': None,
#   'postal_code': '80109-1585',
#   'country': 'United States',
#   'longitude': '-104.8667206',
#   'latitude': '39.38269495',
#   'phone': '3033257321',
#   'website_url': 'http://www.105westbrewing.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10k-brewing-anoka',
#   'name': '10K Brewing',
#   'brewery_type': 'micro',
#   'street': '2005 2nd Ave',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Anoka',
#   'state': 'Minnesota',
#   'county_province': None,
#   'postal_code': '55303-2243',
#   'country': 'United States',
#   'longitude': '-93.38952559',
#   'latitude': '45.19812039',
#   'phone': '7633924753',
#   'website_url': 'http://10KBrew.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '10th-district-brewing-company-abington',
#   'name': '10th District Brewing Company',
#   'brewery_type': 'micro',
#   'street': '491 Washington St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Abington',
#   'state': 'Massachusetts',
#   'county_province': None,
#   'postal_code': '02351-2419',
#   'country': 'United States',
#   'longitude': '-70.94594149',
#   'latitude': '42.10591754',
#   'phone': '7813071554',
#   'website_url': 'http://www.10thdistrictbrewing.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '11-below-brewing-company-houston',
#   'name': '11 Below Brewing Company',
#   'brewery_type': 'micro',
#   'street': '6820 Bourgeois Rd',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Houston',
#   'state': 'Texas',
#   'county_province': None,
#   'postal_code': '77066-3107',
#   'country': 'United States',
#   'longitude': '-95.5186591',
#   'latitude': '29.9515464',
#   'phone': '2814442337',
#   'website_url': 'http://www.11belowbrewing.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '1188-brewing-co-john-day',
#   'name': '1188 Brewing Co',
#   'brewery_type': 'brewpub',
#   'street': '141 E Main St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'John Day',
#   'state': 'Oregon',
#   'county_province': None,
#   'postal_code': '97845-1210',
#   'country': 'United States',
#   'longitude': '-118.9218754',
#   'latitude': '44.4146563',
#   'phone': '5415751188',
#   'website_url': 'http://www.1188brewing.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '12-acres-brewing-company-killeshin',
#   'name': '12 Acres Brewing Company',
#   'brewery_type': 'micro',
#   'street': 'Unnamed Street',
#   'address_2': 'Clonmore',
#   'address_3': None,
#   'city': 'Killeshin',
#   'state': None,
#   'county_province': 'Laois',
#   'postal_code': 'R93 X3X8',
#   'country': 'Ireland',
#   'longitude': '-6.979343891',
#   'latitude': '52.84930763',
#   'phone': '+353599107299',
#   'website_url': 'https://12acresbrewing.ie/',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '12-gates-brewing-company-williamsville',
#   'name': '12 Gates Brewing Company',
#   'brewery_type': 'brewpub',
#   'street': '80 Earhart Dr Ste 20',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Williamsville',
#   'state': 'New York',
#   'county_province': None,
#   'postal_code': '14221-7804',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '7169066600',
#   'website_url': 'http://www.12gatesbrewing.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '12-west-brewing-company-gilbert',
#   'name': '12 West Brewing Company',
#   'brewery_type': 'micro',
#   'street': '3000 E Ray Rd Bldg 6',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Gilbert',
#   'state': 'Arizona',
#   'county_province': None,
#   'postal_code': '85296-7832',
#   'country': 'United States',
#   'longitude': None,
#   'latitude': None,
#   'phone': '6023395014',
#   'website_url': 'http://www.12westbrewing.com',
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'},
#  {'id': '12-west-brewing-company-production-facility-mesa',
#   'name': '12 West Brewing Company - Production Facility',
#   'brewery_type': 'micro',
#   'street': None,
#   'address_2': None,
#   'address_3': None,
#   'city': 'Mesa',
#   'state': 'Arizona',
#   'county_province': None,
#   'postal_code': '85207',
#   'country': 'United States',
#   'longitude': '-111.5860662',
#   'latitude': '33.436188',
#   'phone': None,
#   'website_url': None,
#   'updated_at': '2022-10-30T06:11:39.514Z',
#   'created_at': '2022-10-30T06:11:39.514Z'}]

# %%
json = response.json()

# %%
pd.json_normalize(json)
# Out:
#                                            id  \
# 0  hometown-cellars-winery-and-brewery-ithaca
# 1                       ithaca-beer-co-ithaca
# 2         liquid-state-brewing-company-ithaca
# 3          scale-house-brewery-and-pub-ithaca
#
#                                 name brewery_type                 street  \
# 0  Hometown Cellars Winery & Brewery        micro  108 E Center St Ste D
# 1                     Ithaca Beer Co     regional     122 Ithaca Beer Dr
# 2       Liquid State Brewing Company        micro  620 West Green Street
# 3          Scale House Brewery & Pub      brewpub     23 Cinema Dr Ste C
#
#   address_2 address_3    city     state county_province postal_code  \
# 0      None      None  Ithaca  Michigan            None  48847-1453
# 1      None      None  Ithaca  New York            None  14850-8813
# 2      None      None  Ithaca  New York            None       14850
# 3      None      None  Ithaca  New York            None  14850-1682
#
#          country    longitude     latitude       phone  \
# 0  United States         None         None  9898756010
# 1  United States         None         None  6072730766
# 2  United States  -76.5077547  42.43844312        None
# 3  United States         None         None  6072570107
#
#                          website_url                updated_at  \
# 0     http://www.hometowncellars.com  2022-10-30T06:11:39.514Z
# 1          http://www.ithacabeer.com  2022-10-30T06:11:39.514Z
# 2  http://www.liquidstatebrewing.com  2022-10-30T06:11:39.514Z
# 3   http://www.scalehousebrewpub.com  2022-10-30T06:11:39.514Z
#
#                  created_at
# 0  2022-10-30T06:11:39.514Z
# 1  2022-10-30T06:11:39.514Z
# 2  2022-10-30T06:11:39.514Z
# 3  2022-10-30T06:11:39.514Z

# %% [markdown]
# ## List Breweries Paramaters

# %% [markdown]
# - by_city
# - by_name
# - by_state
# - by_postal
# - by_type
# - page
# - per_page
# - sort

# %% [markdown]
# ### By City

# %% [markdown]
# https://api.openbrewerydb.org/breweries?by_city=Ithaca

# %%
city = 'Ithaca'

# %%
response = requests.get(f"https://api.openbrewerydb.org/breweries?by_city={city}")
json = response.json()

# %%
pd.json_normalize(json)
# Out:
#                                            id  \
# 0  hometown-cellars-winery-and-brewery-ithaca
# 1                       ithaca-beer-co-ithaca
# 2         liquid-state-brewing-company-ithaca
# 3          scale-house-brewery-and-pub-ithaca
#
#                                 name brewery_type                 street  \
# 0  Hometown Cellars Winery & Brewery        micro  108 E Center St Ste D
# 1                     Ithaca Beer Co     regional     122 Ithaca Beer Dr
# 2       Liquid State Brewing Company        micro  620 West Green Street
# 3          Scale House Brewery & Pub      brewpub     23 Cinema Dr Ste C
#
#   address_2 address_3    city     state county_province postal_code  \
# 0      None      None  Ithaca  Michigan            None  48847-1453
# 1      None      None  Ithaca  New York            None  14850-8813
# 2      None      None  Ithaca  New York            None       14850
# 3      None      None  Ithaca  New York            None  14850-1682
#
#          country    longitude     latitude       phone  \
# 0  United States         None         None  9898756010
# 1  United States         None         None  6072730766
# 2  United States  -76.5077547  42.43844312        None
# 3  United States         None         None  6072570107
#
#                          website_url                updated_at  \
# 0     http://www.hometowncellars.com  2022-10-30T06:11:39.514Z
# 1          http://www.ithacabeer.com  2022-10-30T06:11:39.514Z
# 2  http://www.liquidstatebrewing.com  2022-10-30T06:11:39.514Z
# 3   http://www.scalehousebrewpub.com  2022-10-30T06:11:39.514Z
#
#                  created_at
# 0  2022-10-30T06:11:39.514Z
# 1  2022-10-30T06:11:39.514Z
# 2  2022-10-30T06:11:39.514Z
# 3  2022-10-30T06:11:39.514Z

# %% [markdown]
# ## By Type

# %% [markdown]
# https://api.openbrewerydb.org/breweries?by_city=Ithaca&by_type=micro

# %%
city = 'Ithaca'
brew_type = 'micro'

# %%
response = requests.get(f"https://api.openbrewerydb.org/breweries?by_city={city}&by_type={brew_type}")
json = response.json()

# %%
pd.json_normalize(json)

# %% [markdown]
# ## Search Breweries

# %% [markdown]
# https://api.openbrewerydb.org/breweries/search?query=dog

# %%
query = 'four'

# %%
response = requests.get(f"https://api.openbrewerydb.org/breweries/search?query={query}")
json = response.json()

# %%
pd.json_normalize(json)
# Out:
#                                                            id  \
# 0                             forest-city-brewing-middlefield
# 1                                     forge-brew-works-lorton
# 2                                 fort-george-brewery-astoria
# 3                               fort-hill-brewery-easthampton
# 4                               fort-myers-brewing-fort-myers
# 5                                  fort-orange-brewing-albany
# 6                       fort-point-beer-company-san-francisco
# 7                          fortside-brewing-company-vancouver
# 8                         fossil-cove-brewing-co-fayetteville
# 9                       fossil-craft-beer-co-colorado-springs
# 10                                   forge-brewhouse-sycamore
# 11                    forgotten-boardwalk-brewing-cherry-hill
# 12                                 forgotten-road-ales-graham
# 13                          fort-brewery-and-pizza-fort-worth
# 14                      fort-smith-brewing-company-fort-smith
# 15                           fort-street-brewery-lincoln-park
# 16                             fortnight-brewing-company-cary
# 17  forward-operating-base-brewing-company-fob-brewing-dupont
# 18                            fossil-fuels-brewing-co-fremont
# 19                                third-place-brewing-wichita
# 20                           fort-rock-brewing-rancho-cordova
# 21                                  mad-mouse-brewery-chicago
# 22                              fosters-pint-and-plate-rogers
# 23                                   rising-sons-brewery-cork
# 24          the-lodge-restaurant-and-microbrewery-sugar-grove
# 25                            edward-teach-brewing-wilmington
# 26                     six-harbors-brewing-company-huntington
# 27                                    993993-praha-suyeong-gu
#
#                                                     name brewery_type  \
# 0                                    Forest City Brewing        micro
# 1                                       Forge Brew Works      brewpub
# 2                                    Fort George Brewery     regional
# 3                                      Fort Hill Brewery        micro
# 4                                     Fort Myers Brewing        micro
# 5                                    Fort Orange Brewing        micro
# 6                                Fort Point Beer Company     regional
# 7                               Fortside Brewing Company        micro
# 8                                 Fossil Cove Brewing Co      brewpub
# 9                                   Fossil Craft Beer Co        micro
# 10                                       Forge Brewhouse      brewpub
# 11                           Forgotten Boardwalk Brewing        micro
# 12                                   Forgotten Road Ales     planning
# 13                                Fort Brewery and Pizza      brewpub
# 14                            Fort Smith Brewing Company        micro
# 15                                   Fort Street Brewery      brewpub
# 16                             Fortnight Brewing Company        micro
# 17  Forward Operating Base Brewing Company / FOB Brewing        micro
# 18                               Fossil Fuels Brewing Co     contract
# 19                                   Third Place Brewing        micro
# 20                                     Fort Rock Brewing        micro
# 21                                     Mad Mouse Brewery     contract
# 22                                 Foster's Pint & Plate      brewpub
# 23                                   Rising Sons Brewery        micro
# 24                   The Lodge Restaurant & Microbrewery      brewpub
# 25                                  Edward Teach Brewing        micro
# 26                           Six Harbors Brewing Company   proprietor
# 27                                     프라하993(993 Praha)      brewpub
#
#                             street address_2 address_3              city  \
# 0                  180 Johnson St.      None      None       Middlefield
# 1           8532 Terminal Rd Ste M      None      None            Lorton
# 2                    1483 Duane St      None      None           Astoria
# 3                  30 Fort Hill Rd      None      None       Easthampton
# 4   12811 Commerce Lakes Dr Ste 28      None      None        Fort Myers
# 5                   450 N Pearl St      None      None            Albany
# 6                     644 Mason St      None      None     San Francisco
# 7        2200 NE Andresen Rd Ste B      None      None         Vancouver
# 8                 1946 N Birch Ave      None      None      Fayetteville
# 9           2845 Ore Mill Rd Ste 1      None      None  Colorado Springs
# 10                 1330 E State St      None      None          Sycamore
# 11          1940 Olney Ave Ste 100      None      None       Cherry Hill
# 12                            None      None      None            Graham
# 13             1001 W Magnolia Ave      None      None        Fort Worth
# 14          7500 Fort Chaffee Blvd      None      None        Fort Smith
# 15                    1660 Fort St      None      None      Lincoln Park
# 16             211 Powers Ferry Rd      None      None              Cary
# 17      2750 Williamson Pl Ste 100      None      None            Dupont
# 18                  45928 Omega Dr      None      None           Fremont
# 19   630 E Douglas Ave  Suite #150      None      None           Wichita
# 20       12401 Folsom Blvd Ste 110      None      None    Rancho Cordova
# 21                            None      None      None           Chicago
# 22          2001 S Bellview Rd # 2      None      None            Rogers
# 23                   Cornmarket St      None      None              Cork
# 24        29042 Hide AWay Hills Rd      None      None       Sugar Grove
# 25                    604 N 4th St      None      None        Wilmington
# 26               243 New York Ave.      None      None        Huntington
# 27        20, Gurak-ro 123beon-gil      None      None        Suyeong-gu
#
#              state county_province postal_code        country  \
# 0      Connecticut            None        6455  United States
# 1         Virginia            None  22079-1428  United States
# 2           Oregon            None  97103-3819  United States
# 3    Massachusetts            None  01027-1268  United States
# 4          Florida            None  33913-8649  United States
# 5         New York            None  12204-1511  United States
# 6       California            None  94129-1600  United States
# 7       Washington            None  98661-7350  United States
# 8         Arkansas            None  72703-2408  United States
# 9         Colorado            None  80904-3161  United States
# 10        Illinois            None  60178-9580  United States
# 11      New Jersey            None  08003-2016  United States
# 12  North Carolina            None       27253  United States
# 13           Texas            None  76104-4504  United States
# 14        Arkansas            None  72916-6086  United States
# 15        Michigan            None  48146-1909  United States
# 16  North Carolina            None  27519-1510  United States
# 17      Washington            None  98327-7501  United States
# 18      California            None  94539-6848  United States
# 19          Kansas            None  67202-3537  United States
# 20      California            None  95742-6422  United States
# 21        Illinois            None  60607-5017  United States
# 22        Arkansas            None  72758-4050  United States
# 23            None            Cork    T12 WK27        Ireland
# 24            Ohio            None       43155  United States
# 25  North Carolina            None       28401  United States
# 26        New York            None  11743-2719  United States
# 27           Busan            None       48212    South Korea
#
#               longitude            latitude          phone  \
# 0                  None                None     8607882138
# 1                  None                None     7033722979
# 2          -123.8274681          46.1883837     5033257468
# 3          -72.64143098         42.28503154     4132035754
# 4           -81.7619411          26.5611037     9162343332
# 5             -73.74427            42.66372     5189923103
# 6          -122.4102278         37.78946124     4159064021
# 7   -122.60116433068708  45.639116415942944     3605244692
# 8          -94.16478287          36.0879053     4796444601
# 9                  None                None     7193758298
# 10            -88.66048           41.984784           None
# 11                 None                None     8564370709
# 12                 None                None     4342031993
# 13         -97.33528782          32.7303843     5125697369
# 14           -94.298483           35.310777     4792423722
# 15         -83.17610229         42.25215845     3133899620
# 16         -78.91133714         35.80576231     9194340742
# 17          -122.625039           47.107496     2535074667
# 18         -121.9215949          37.4989939     5103815739
# 19                 None                None           None
# 20         -121.2248778         38.62586534     9169364616
# 21                 None                None           None
# 22                 None                None           None
# 23           -8.4787177          51.8995943  +353212414764
# 24                 None                None     7405697944
# 25           -77.945422           34.242576     9105235401
# 26          -73.4253168          40.8749628     5166803528
# 27   129.11542954562745   35.17760200598895   051-757-2703
#
#                            website_url                updated_at  \
# 0                                 None  2022-10-30T06:11:39.514Z
# 1        http://www.forgebrewworks.com  2022-10-30T06:11:39.514Z
# 2     http://www.fortgeorgebrewery.com  2022-10-30T06:11:39.514Z
# 3       http://www.forthillbrewery.com  2022-10-30T06:11:39.514Z
# 4                                 None  2022-10-30T06:11:39.514Z
# 5     http://www.fortorangebrewing.com  2022-10-30T06:11:39.514Z
# 6         http://www.fortpointbeer.com  2022-10-30T06:11:39.514Z
# 7       http://www.fortsidebrewing.com  2022-10-30T06:11:39.514Z
# 8     http://www.fossilcovebrewing.com  2022-10-30T06:11:39.514Z
# 9       http://www.fossilcraftbeer.com  2022-10-30T06:11:39.514Z
# 10                                None  2022-10-30T06:11:39.514Z
# 11   http://www.forgottenboardwalk.com  2022-10-30T06:11:39.514Z
# 12                                None  2022-10-30T06:11:39.514Z
# 13          http://www.fortbrewery.com  2022-10-30T06:11:39.514Z
# 14             http://www.fsbrewco.com  2022-10-30T06:11:39.514Z
# 15       http://www.fortstreetbeer.com  2022-10-30T06:11:39.514Z
# 16     http://www.fortnightbrewing.com  2022-10-30T06:11:39.514Z
# 17    http://www.fobbrewingcompany.com  2022-10-30T06:11:39.514Z
# 18                                None  2022-10-30T06:11:39.514Z
# 19       http://www.thirdplacebrew.com  2022-10-30T06:11:39.514Z
# 20      http://www.fortrockbrewing.com  2022-10-30T06:11:39.514Z
# 21      http://www.moxeerestaurant.com  2022-10-30T06:11:39.514Z
# 22  http://www.fosterspintandplate.com  2022-10-30T06:11:39.514Z
# 23   http://www.risingsonsbrewery.com/  2022-10-30T06:11:39.514Z
# 24   http://www.hideawayhillslodge.com  2022-10-30T06:11:39.514Z
# 25                                None  2022-10-30T06:11:39.514Z
# 26                                None  2022-10-30T06:11:39.514Z
# 27                http://praha993.com/  2022-10-30T06:11:39.514Z
#
#                   created_at
# 0   2022-10-30T06:11:39.514Z
# 1   2022-10-30T06:11:39.514Z
# 2   2022-10-30T06:11:39.514Z
# 3   2022-10-30T06:11:39.514Z
# 4   2022-10-30T06:11:39.514Z
# 5   2022-10-30T06:11:39.514Z
# 6   2022-10-30T06:11:39.514Z
# 7   2022-10-30T06:11:39.514Z
# 8   2022-10-30T06:11:39.514Z
# 9   2022-10-30T06:11:39.514Z
# 10  2022-10-30T06:11:39.514Z
# 11  2022-10-30T06:11:39.514Z
# 12  2022-10-30T06:11:39.514Z
# 13  2022-10-30T06:11:39.514Z
# 14  2022-10-30T06:11:39.514Z
# 15  2022-10-30T06:11:39.514Z
# 16  2022-10-30T06:11:39.514Z
# 17  2022-10-30T06:11:39.514Z
# 18  2022-10-30T06:11:39.514Z
# 19  2022-10-30T06:11:39.514Z
# 20  2022-10-30T06:11:39.514Z
# 21  2022-10-30T06:11:39.514Z
# 22  2022-10-30T06:11:39.514Z
# 23  2022-10-30T06:11:39.514Z
# 24  2022-10-30T06:11:39.514Z
# 25  2022-10-30T06:11:39.514Z
# 26  2022-10-30T06:11:39.514Z
# 27  2022-10-30T06:11:39.514Z

# %% [markdown]
# ### Your Turn!

# %% [markdown]
# Search for your own keyword by changing the `query` variable above! Or create your own API request entirely.
#
# **Discuss**: What kind of projects or research questions do you think you (or someone else) could do with data from the Open Brewery Database API?

# %% [markdown]
# ## Open Library API

# %% [markdown]
# https://openlibrary.org/developers/api

# %% [markdown]
# Open Library API Endpoints
# - Books
# - Covers
# - Lists
# - Read
# - Recent Changes
# - Search
# - Search inside
# - Subjects

# %% [markdown]
# ## Search
# http://openlibrary.org/search.json
#
# - Query
# - Author
# - Title

# %% [markdown]
# ### Author

# %%
author = 'Sandra Cisneros'

# %%
response = requests.get(f"http://openlibrary.org/search.json?author={author}")

# %%
response.json()
# Out:
# {'location': '/works/OL3243765W',
#  'key': '/works/OL3243784W',
#  'type': {'key': '/type/redirect'},
#  'latest_revision': 28,
#  'revision': 28,
#  'created': {'type': '/type/datetime', 'value': '2009-12-10T03:04:07.997442'},
#  'last_modified': {'type': '/type/datetime',
#   'value': '2021-04-12T10:31:19.904649'}}

# %%
# pd.json_normalize(response.json()['docs'])

# %% [markdown]
# ### Your Turn!

# %% [markdown]
# Search for your own author by changing the `author` variable above!
#
# **Discuss**: What do you notice about the data returned? What's confusing or surprising? How might this data be useful?

# %% [markdown]
# ### Books

# %% [markdown]
# https://openlibrary.org/works/OL3243784W.json

# %%
response = requests.get("https://openlibrary.org/works/OL3243784W.json")
json = response.json()

# %%
json
# Out:
# {'location': '/works/OL3243765W',
#  'key': '/works/OL3243784W',
#  'type': {'key': '/type/redirect'},
#  'latest_revision': 28,
#  'revision': 28,
#  'created': {'type': '/type/datetime', 'value': '2009-12-10T03:04:07.997442'},
#  'last_modified': {'type': '/type/datetime',
#   'value': '2021-04-12T10:31:19.904649'}}

# %% [markdown]
# ### Covers

# %% [markdown]
# `http://covers.openlibrary.org/b/id/{value}-{size}.jpg`

# %% [markdown]
# https://covers.openlibrary.org/b/id/6374495-M.jpg

# %% [markdown]
# ![](https://covers.openlibrary.org/b/id/6374495-M.jpg)

# %% [markdown]
# # Pandas Basics — More Useful Methods — Workbook

# %% [markdown]
# ___

# %% [markdown]
# ## Dataset
# ### *The Pudding*'s Film Dialogue Data

# %% [markdown]
# The dataset that we're working with in this lesson is taken from Hannah Andersen and Matt Daniels's *Pudding* essay, ["Film Dialogue from 2,000 screenplays, Broken Down by Gender and Age"](https://pudding.cool/2017/03/film-dialogue/). The dataset provides information about 2,000 films from 1925 to 2015, including characters’ names, genders, ages, how many words each character spoke in each film, the release year of each film, and how much money the film grossed. They included character gender information because they wanted to contribute data to a broader conversation about how "white men dominate movie roles."

# %% [markdown]
# ___

# %% [markdown]
# ## Import Pandas

# %% [markdown]
# To use the Pandas library, we first need to `import` it.

# %%
import pandas as pd

# %% [markdown]
# ## Change Display Settings

# %% [markdown]
# By default, Pandas will display 60 rows and 20 columns. I often change [Pandas' default display settings](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html) to show more rows or columns.

# %%
pd.options.display.max_rows = 200

# %% [markdown]
# ## Get Data

# %% [markdown]
# For this notebook, we're going to read in a slightly less clean version of the Pudding data.

# %%
film_df = pd.read_csv('../data/Pudding/Pudding-Film-Dialogue-Salty.csv', delimiter=",", encoding='utf-8')

# %% [markdown]
# ## Overview
#
# To look at a random *n* number of rows in a DataFrame, we can use a method called `.sample()`.

# %%
film_df.sample(5)
# Out:
#        script_id imdb_character_name  words gender   age    imdb_id  \
# 11628       3729                girl   2424      f  24.0  tt0486051
# 7617        2584             matthew    490      m  34.0  tt1242432
# 355          714       orchid dothan    275      f  57.0  tt0215545
# 18578       7075                bull   1264      m  56.0  tt0061619
# 15716       5298      harry kawamura    235      m   NaN  tt0099291
#
#                        title  year  gross  proportion_of_dialogue
# 11628             Wind Chill  2007    NaN                0.496416
# 7617    I Spit on Your Grave  2010    NaN                0.032028
# 355               Bamboozled  2000    3.0                0.023982
# 18578              El Dorado  1966   47.0                0.108405
# 15716  Come See the Paradise  1990    1.0                0.033225

# %% [markdown]
# Generate information about all the columns in the data

# %%
film_df.describe()
# Out:
#           script_id         words           age          year         gross  \
# count  23052.000000  23052.000000  18266.000000  23052.000000  19390.000000
# mean    4195.580904    907.870684     42.386839   1998.133828    106.805570
# std     2473.518048   1399.538583     59.714730     14.745342    145.992394
# min      280.000000    101.000000      3.000000   1929.000000      0.000000
# 25%     2095.000000    193.000000     30.000000   1992.000000     22.000000
# 50%     3694.000000    396.000000     39.000000   2001.000000     56.000000
# 75%     6234.000000    980.000000     50.000000   2009.000000    136.000000
# max     9254.000000  28102.000000   2013.000000   2015.000000   1798.000000
#
#        proportion_of_dialogue
# count            23052.000000
# mean                 0.086512
# std                  0.107740
# min                  0.001537
# 25%                  0.019771
# 50%                  0.042421
# 75%                  0.104166
# max                  0.923422

# %% [markdown]
# ## Rename Columns

# %%
film_df = film_df.rename(columns={'imdb_character_name': 'character', 'year': 'release_year'})

# %% [markdown]
# ## Clean and Transform Data

# %% [markdown]
# ### Pandas `.str` Methods

# %% [markdown]
# Remember all the special things that you can do with Python strings aka [string methods](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Python/String-Methods.html)?
#
# Pandas has special [Pandas string methods](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#string-methods), too. Many of them are very similar to Python string methods, except they will transform every single string value in a column, and we have to add `.str` to the method chain.

# %% [markdown]
# | **Pandas String Method** | **Explanation**                                                                                   |
# |:-------------:|:---------------------------------------------------------------------------------------------------:|
# | df['column_name']`.str.lower()`         | makes the string in each row lowercase                                                                                |
# | df['column_name']`.str.upper()`         | makes the string in each row uppercase                                                |
# | df['column_name']`.str.title()`         | makes the string in each row titlecase                                                |
# | df['column_name']`.str.replace('old string', 'new string')`      | replaces `old string` with `new string` for each row |
# | df['column_name']`.str.contains('some string')`      | tests whether string in each row contains "some string" |
# | df['column_name']`.str.split('delim')`          | returns a list of substrings separated by the given delimiter |
# | df['column_name']`.str.join(list)`         | opposite of split(), joins the elements in the given list together using the string                                                                        |

# %% [markdown]
# For example, to transform every character's name in the "character" column from lowercase to title case, we can use `.str.title()`

# %% [markdown]
# To transform every character's name in the "character" column to lowercase, we can use `.str.lower()`

# %%
film_df['character']
# Out:
# 0                  betty
# 1        carolyn johnson
# 2                eleanor
# 3        francesca johns
# 4                  madge
#               ...
# 23047            maurice
# 23048    monsieur d'arqu
# 23049         mrs. potts
# 23050           wardrobe
# 23051         mrs. potts
# Name: character, Length: 23052, dtype: object

# %%
film_df['character'].str.title()
# Out:
# 0                  Betty
# 1        Carolyn Johnson
# 2                Eleanor
# 3        Francesca Johns
# 4                  Madge
#               ...
# 23047            Maurice
# 23048    Monsieur D'Arqu
# 23049         Mrs. Potts
# 23050           Wardrobe
# 23051         Mrs. Potts
# Name: character, Length: 23052, dtype: object

# %% [markdown]
# The transformation above was temporary. Change the DataFrame column "character" to title case permanently.

# %%
#Your code here

# %% [markdown]
# ## Filter with `.contains()`

# %% [markdown]
# We can use the `.str.contains()` to search for particular words or phrases in a column, such as "Star Wars."

# %%
star_wars_filter = film_df['title'].str.contains('Star Wars')

# %%
film_df[star_wars_filter]
# Out:
#        script_id        character  words gender   age    imdb_id  \
# 3017        1359   admiral ackbar    199      m  61.0  tt0086190
# 3018        1359  ben 'obi-wan' k    462      m  69.0  tt0086190
# 3019        1359            c-3po    881      m  37.0  tt0086190
# 3020        1359      darth vader    381      m  48.0  tt0086190
# 3021        1359         han solo    835      m  41.0  tt0086190
# 3022        1359  lando calrissia    379      m  46.0  tt0086190
# 3023        1359   luke skywalker    915      m  32.0  tt0086190
# 3024        1359    princess leia    359      f  27.0  tt0086190
# 3025        1359      the emperor    516      m  39.0  tt0086190
# 3026        1359             yoda    163      m  19.0  tt0086190
# 3027        1360  anakin skywalke   2061      m  21.0  tt0121765
# 3028        1360      cliegg lars    152      m  62.0  tt0121765
# 3029        1360      count dooku    321      m  80.0  tt0121765
# 3030        1360  dexter jettster    151      m  67.0  tt0121765
# 3031        1360    jar jar binks    294      m  29.0  tt0121765
# 3032        1360          lama su    350      m  48.0  tt0121765
# 3033        1360       mace windu    365      m  54.0  tt0121765
# 3034        1360  madame jocasta     331      f  82.0  tt0121765
# 3035        1360   obi-wan kenobi   1477      m  31.0  tt0121765
# 3036        1360            padme    668      f  21.0  tt0121765
# 3037        1360   queen jamillia    135      f  25.0  tt0121765
# 3038        1360  supreme chancel    576      m  58.0  tt0121765
# 3039        1360          taun we    139      f  40.0  tt0121765
# 3040        1360            watto    140      m  49.0  tt0121765
# 3041        1360             yoda    355      m  58.0  tt0121765
# 3058        1362  ben obi-wan ken    995      m  63.0  tt0076759
# 3059        1362            c-3po   1506      m  31.0  tt0076759
# 3060        1362  cmdr. praji (im    117      m  42.0  tt0076759
# 3061        1362      darth vader    492      m  46.0  tt0076759
# 3062        1362  general dodonna    185      m  66.0  tt0076759
# 3063        1362  grand moff tark    411      m  64.0  tt0076759
# 3064        1362           greedo    103      m  33.0  tt0076759
# 3065        1362         han solo   1730      m  35.0  tt0076759
# 3066        1362            jabba    185      m   NaN  tt0076759
# 3067        1362   luke skywalker   2485      m  26.0  tt0076759
# 3068        1362  princess leia o    636      f  21.0  tt0076759
# 3069        1362       red leader    241      m  37.0  tt0076759
# 3070        1362  red three (bigg    523      m  38.0  tt0076759
# 3071        1362     stormtrooper    122      m  36.0  tt0076759
# 3072        1362       uncle owen    311      m  61.0  tt0076759
# 10591       3427  anakin skywalke   3768      m  24.0  tt0121766
# 10592       3427            c-3po    312      m  59.0  tt0121766
# 10593       3427  Clone Jedi Knig    104      m   NaN  tt0121766
# 10594       3427    darth sldious    244      m   NaN  tt0121766
# 10595       3427  general grievou    317      m  33.0  tt0121766
# 10596       3427  Ki-Adi-Mundi /     107      m  40.0  tt0121766
# 10597       3427       Mace Windu    407      m  57.0  tt0121766
# 10598       3427       mon mothma    127      f  28.0  tt0121766
# 10599       3427   obi-wan kenobi   3181      m  34.0  tt0121766
# 10600       3427            Padme   1561      f  24.0  tt0121766
# 10601       3427  senator bail or    479      m  50.0  tt0121766
# 10602       3427  Supreme Chancel   2367      m  61.0  tt0121766
# 10603       3427             yoda    923      m  61.0  tt0121766
# 10604       3433    admiral piett    232      m  43.0  tt0080684
# 10605       3433  ben (obi-wan) k    177      m  66.0  tt0080684
# 10606       3433            C-3PO   1474      m  34.0  tt0080684
# 10607       3433    captain needa    108      m  42.0  tt0080684
# 10608       3433      darth vader    853      m  49.0  tt0080684
# 10609       3433    general veers    114      m  45.0  tt0080684
# 10610       3433         han solo   2024      m  38.0  tt0080684
# 10611       3433  lando calrissia    798      m  43.0  tt0080684
# 10612       3433   luke skywalker   1282      m  29.0  tt0080684
# 10613       3433    princess leia   1025      f  24.0  tt0080684
# 10614       3433  rebel force gen    168      m  50.0  tt0080684
# 10615       3433    snow creature    227      m   NaN  tt0080684
# 10616       3433             yoda    751      m  36.0  tt0080684
# 10617       3437  anakin skywalke   1697      m  10.0  tt0120915
# 10618       3437        boss nass    209      m  63.0  tt0120915
# 10619       3437   Captain Panaka    390      m  45.0  tt0120915
# 10620       3437  chancellor valo    127      m  61.0  tt0120915
# 10621       3437    darth sidious    277      m   NaN  tt0120915
# 10622       3437    jar jar binks    632      m  26.0  tt0120915
# 10623       3437       mace windu    247      m  51.0  tt0120915
# 10624       3437      nute gunray    544      m  34.0  tt0120915
# 10625       3437   obi-wan kenobi    701      m  28.0  tt0120915
# 10626       3437            padme    718      f  18.0  tt0120915
# 10627       3437    queen amidala    656      f  18.0  tt0120915
# 10628       3437     qui-gon jinn   2339      m  47.0  tt0120915
# 10629       3437         ric oli�    132      m  42.0  tt0120915
# 10630       3437       rune haako    126      m   NaN  tt0120915
# 10631       3437  Senator Palpati    551      m  55.0  tt0120915
# 10632       3437   shmi skywalker    414      f  41.0  tt0120915
# 10633       3437       sio bibble    164      m  60.0  tt0120915
# 10634       3437            watto    502      m  46.0  tt0120915
# 10635       3437             yoda    312      m  55.0  tt0120915
# 21000       8099         bala-tik    140      m   NaN  tt2488496
# 21001       8099            c-3po    138      m  69.0  tt2488496
# 21002       8099            c-3po    138      m  69.0  tt2488496
# 21003       8099             finn   1447      m  23.0  tt2488496
# 21004       8099      general hux    356      m  32.0  tt2488496
# 21005       8099         han solo   1225      m  73.0  tt2488496
# 21006       8099         kylo ren    618      m  32.0  tt2488496
# 21007       8099       maz kanata    241      f  32.0  tt2488496
# 21008       8099      poe dameron    604      m  36.0  tt2488496
# 21009       8099    princess leia    252      f  59.0  tt2488496
# 21010       8099              rey   1363      f  23.0  tt2488496
# 21011       8099     stormtrooper    114      m   NaN  tt2488496
# 21012       8099  supreme leader     168      m  51.0  tt2488496
#
#                                                 title  release_year   gross  \
# 3017       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3018       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3019       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3020       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3021       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3022       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3023       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3024       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3025       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3026       Star Wars: Episode VI - Return of the Jedi          1983   853.0
# 3027     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3028     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3029     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3030     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3031     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3032     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3033     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3034     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3035     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3036     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3037     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3038     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3039     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3040     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3041     Star Wars: Episode II - Attack of the Clones          2002   465.0
# 3058               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3059               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3060               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3061               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3062               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3063               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3064               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3065               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3066               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3067               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3068               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3069               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3070               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3071               Star Wars: Episode IV - A New Hope          1977  1798.0
# 3072               Star Wars: Episode IV - A New Hope          1977  1798.0
# 10591    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10592    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10593    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10594    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10595    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10596    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10597    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10598    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10599    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10600    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10601    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10602    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10603    Star Wars: Episode III - Revenge of the Sith          2005   515.0
# 10604  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10605  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10606  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10607  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10608  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10609  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10610  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10611  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10612  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10613  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10614  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10615  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10616  Star Wars: Episode V - The Empire Strikes Back          1980   937.0
# 10617       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10618       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10619       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10620       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10621       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10622       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10623       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10624       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10625       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10626       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10627       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10628       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10629       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10630       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10631       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10632       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10633       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10634       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 10635       Star Wars: Episode I - The Phantom Menace          1999   813.0
# 21000      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21001      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21002      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21003      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21004      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21005      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21006      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21007      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21008      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21009      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21010      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21011      Star Wars: Episode VII - The Force Awakens          2015   927.0
# 21012      Star Wars: Episode VII - The Force Awakens          2015   927.0
#
#        proportion_of_dialogue
# 3017                 0.039096
# 3018                 0.090766
# 3019                 0.173084
# 3020                 0.074853
# 3021                 0.164047
# 3022                 0.074460
# 3023                 0.179764
# 3024                 0.070530
# 3025                 0.101375
# 3026                 0.032024
# 3027                 0.274251
# 3028                 0.020226
# 3029                 0.042715
# 3030                 0.020093
# 3031                 0.039122
# 3032                 0.046574
# 3033                 0.048570
# 3034                 0.044045
# 3035                 0.196540
# 3036                 0.088889
# 3037                 0.017964
# 3038                 0.076647
# 3039                 0.018496
# 3040                 0.018629
# 3041                 0.047239
# 3058                 0.099084
# 3059                 0.149970
# 3060                 0.011651
# 3061                 0.048994
# 3062                 0.018423
# 3063                 0.040928
# 3064                 0.010257
# 3065                 0.172276
# 3066                 0.018423
# 3067                 0.247461
# 3068                 0.063334
# 3069                 0.023999
# 3070                 0.052081
# 3071                 0.012149
# 3072                 0.030970
# 10591                0.271138
# 10592                0.022451
# 10593                0.007484
# 10594                0.017558
# 10595                0.022811
# 10596                0.007700
# 10597                0.029287
# 10598                0.009139
# 10599                0.228898
# 10600                0.112326
# 10601                0.034468
# 10602                0.170325
# 10603                0.066417
# 10604                0.025127
# 10605                0.019170
# 10606                0.159645
# 10607                0.011697
# 10608                0.092386
# 10609                0.012347
# 10610                0.219214
# 10611                0.086429
# 10612                0.138850
# 10613                0.111015
# 10614                0.018196
# 10615                0.024586
# 10616                0.081339
# 10617                0.158037
# 10618                0.019464
# 10619                0.036320
# 10620                0.011827
# 10621                0.025796
# 10622                0.058856
# 10623                0.023002
# 10624                0.050661
# 10625                0.065282
# 10626                0.066865
# 10627                0.061091
# 10628                0.217825
# 10629                0.012293
# 10630                0.011734
# 10631                0.051313
# 10632                0.038555
# 10633                0.015273
# 10634                0.046750
# 10635                0.029056
# 21000                0.021002
# 21001                0.020702
# 21002                0.020702
# 21003                0.217072
# 21004                0.053405
# 21005                0.183768
# 21006                0.092709
# 21007                0.036154
# 21008                0.090609
# 21009                0.037804
# 21010                0.204470
# 21011                0.017102
# 21012                0.025203

# %%
twilight_filter = film_df['title'].str.contains('Twilight')

# %%
film_df[twilight_filter]
# Out:
#        script_id        character  words gender   age    imdb_id  \
# 11261       3621     alice cullen    146      f  21.0  tt1099212
# 11262       3621           angela    250      f  18.0  tt1099212
# 11263       3621       bella swan   4934      f  18.0  tt1099212
# 11264       3621      billy black    148      m  55.0  tt1099212
# 11265       3621     charlie swan   1256      m  42.0  tt1099212
# 11266       3621    edward cullen   3680      m  22.0  tt1099212
# 11267       3621             eric    308      m  27.0  tt1099212
# 11268       3621      esme cullen    162      f  33.0  tt1099212
# 11269       3621      jacob black    342      m  16.0  tt1099212
# 11270       3621            james    778      m  26.0  tt1099212
# 11271       3621           jasper    222      m  24.0  tt1099212
# 11272       3621          jessica    624      f  23.0  tt1099212
# 11273       3621          laurent    294      m  29.0  tt1099212
# 11274       3621      mike newton    160      m  21.0  tt1099212
# 11275       3621       mr. molina    250      m   NaN  tt1099212
# 11276       3621            ren�e    584      f  36.0  tt1099212
# 11277       3621          rosalie    186      f  20.0  tt1099212
# 15410       5163       bella swan    846      f  20.0  tt1325004
# 15411       5163  dr. carlisle cu    128      m  37.0  tt1325004
# 15412       5163    edward cullen    677      m  24.0  tt1325004
# 15413       5163      jacob black    419      m  18.0  tt1325004
# 15414       5163      jasper hale    187      m  26.0  tt1325004
# 15415       5163     rosalie hale    111      f  22.0  tt1325004
# 15416       5164     alice cullen   1200      f  22.0  tt1259571
# 15417       5164           angela    138      f  19.0  tt1259571
# 15418       5164              aro    442      m  40.0  tt1259571
# 15419       5164       bella swan   6542      f  19.0  tt1259571
# 15420       5164     charlie swan    878      m  43.0  tt1259571
# 15421       5164  dr. carlisle cu    318      m  36.0  tt1259571
# 15422       5164    edward cullen   2470      m  23.0  tt1259571
# 15423       5164       embry call    396      m  19.0  tt1259571
# 15424       5164            emily    154      f   NaN  tt1259571
# 15425       5164    emmett cullen    152      m  24.0  tt1259571
# 15426       5164      jacob black   3556      m  17.0  tt1259571
# 15427       5164            jared    256      m  23.0  tt1259571
# 15428       5164          jessica    314      f  24.0  tt1259571
# 15429       5164          laurent    492      m  30.0  tt1259571
# 15430       5164     rosalie hale    298      f  21.0  tt1259571
# 15431       5164         sam uley    316      m  34.0  tt1259571
# 15432       5164         victoria    132      f  30.0  tt1259571
#
#                              title  release_year  gross  \
# 11261                     Twilight          2008  231.0
# 11262                     Twilight          2008  231.0
# 11263                     Twilight          2008  231.0
# 11264                     Twilight          2008  231.0
# 11265                     Twilight          2008  231.0
# 11266                     Twilight          2008  231.0
# 11267                     Twilight          2008  231.0
# 11268                     Twilight          2008  231.0
# 11269                     Twilight          2008  231.0
# 11270                     Twilight          2008  231.0
# 11271                     Twilight          2008  231.0
# 11272                     Twilight          2008  231.0
# 11273                     Twilight          2008  231.0
# 11274                     Twilight          2008  231.0
# 11275                     Twilight          2008  231.0
# 11276                     Twilight          2008  231.0
# 11277                     Twilight          2008  231.0
# 15410   The Twilight Saga: Eclipse          2010  331.0
# 15411   The Twilight Saga: Eclipse          2010  331.0
# 15412   The Twilight Saga: Eclipse          2010  331.0
# 15413   The Twilight Saga: Eclipse          2010  331.0
# 15414   The Twilight Saga: Eclipse          2010  331.0
# 15415   The Twilight Saga: Eclipse          2010  331.0
# 15416  The Twilight Saga: New Moon          2009  344.0
# 15417  The Twilight Saga: New Moon          2009  344.0
# 15418  The Twilight Saga: New Moon          2009  344.0
# 15419  The Twilight Saga: New Moon          2009  344.0
# 15420  The Twilight Saga: New Moon          2009  344.0
# 15421  The Twilight Saga: New Moon          2009  344.0
# 15422  The Twilight Saga: New Moon          2009  344.0
# 15423  The Twilight Saga: New Moon          2009  344.0
# 15424  The Twilight Saga: New Moon          2009  344.0
# 15425  The Twilight Saga: New Moon          2009  344.0
# 15426  The Twilight Saga: New Moon          2009  344.0
# 15427  The Twilight Saga: New Moon          2009  344.0
# 15428  The Twilight Saga: New Moon          2009  344.0
# 15429  The Twilight Saga: New Moon          2009  344.0
# 15430  The Twilight Saga: New Moon          2009  344.0
# 15431  The Twilight Saga: New Moon          2009  344.0
# 15432  The Twilight Saga: New Moon          2009  344.0
#
#        proportion_of_dialogue
# 11261                0.010193
# 11262                0.017453
# 11263                0.344457
# 11264                0.010332
# 11265                0.087685
# 11266                0.256911
# 11267                0.021502
# 11268                0.011310
# 11269                0.023876
# 11270                0.054314
# 11271                0.015498
# 11272                0.043563
# 11273                0.020525
# 11274                0.011170
# 11275                0.017453
# 11276                0.040771
# 11277                0.012985
# 15410                0.357264
# 15411                0.054054
# 15412                0.285895
# 15413                0.176943
# 15414                0.078970
# 15415                0.046875
# 15416                0.066467
# 15417                0.007644
# 15418                0.024482
# 15419                0.362357
# 15420                0.048632
# 15421                0.017614
# 15422                0.136812
# 15423                0.021934
# 15424                0.008530
# 15425                0.008419
# 15426                0.196965
# 15427                0.014180
# 15428                0.017392
# 15429                0.027252
# 15430                0.016506
# 15431                0.017503
# 15432                0.007311

# %% [markdown]
# Make your own filter with `.str.contains()`

# %%
new_filter = ...

# %%
# film_df[new_filter]

# %% [markdown]
# ## Applying Functions

# %% [markdown]
# You can apply Python functions to DataFrames with multiple different methods. We will explore two of them here.

# %% [markdown]
# Let's say we want to transform the "gross" column, which reports how much money each film made, into a full number. Right now if a film made $2 million, it simply says `2.0`. But maybe we want it to say `20000000`.

# %%
def make_millions(number):
    new_number = number * 1000000
    return new_number

# %%
make_millions(2.0)
# Out:
# 2000000.0

# %% [markdown]
# ### Method 1
#
# You can use regular Python to loop through the Series `film_df['gross']` and make a list with all your new values.

# %%
gross_in_millions = []
for gross in film_df['gross']:
    gross_mill = make_millions(gross)
    gross_in_millions.append(gross_mill)

# %% [markdown]
# Then you can add that list as a new column to the DataFrame.

# %%
film_df['gross_millions'] = gross_in_millions

# %%
film_df
# Out:
#        script_id        character  words gender   age    imdb_id  \
# 0            280            betty    311      f  35.0  tt0112579
# 1            280  carolyn johnson    873      f   NaN  tt0112579
# 2            280          eleanor    138      f   NaN  tt0112579
# 3            280  francesca johns   2251      f  46.0  tt0112579
# 4            280            madge    190      f  46.0  tt0112579
# ...          ...              ...    ...    ...   ...        ...
# 23047       9254          maurice   1107      m  71.0  tt0101414
# 23048       9254  monsieur d'arqu    114      m  58.0  tt0101414
# 23049       9254       mrs. potts    564      f  66.0  tt0101414
# 23050       9254         wardrobe    121      f  54.0  tt0101414
# 23051       9254       mrs. potts    564      f  66.0  tt0101414
#
#                                title  release_year  gross  \
# 0      The Bridges of Madison County          1995  142.0
# 1      The Bridges of Madison County          1995  142.0
# 2      The Bridges of Madison County          1995  142.0
# 3      The Bridges of Madison County          1995  142.0
# 4      The Bridges of Madison County          1995  142.0
# ...                              ...           ...    ...
# 23047           Beauty and the Beast          1991  452.0
# 23048           Beauty and the Beast          1991  452.0
# 23049           Beauty and the Beast          1991  452.0
# 23050           Beauty and the Beast          1991  452.0
# 23051           Beauty and the Beast          1991  452.0
#
#        proportion_of_dialogue  gross_millions
# 0                    0.048639     142000000.0
# 1                    0.136534     142000000.0
# 2                    0.021583     142000000.0
# 3                    0.352049     142000000.0
# 4                    0.029715     142000000.0
# ...                       ...             ...
# 23047                0.108967     452000000.0
# 23048                0.011222     452000000.0
# 23049                0.055517     452000000.0
# 23050                0.011911     452000000.0
# 23051                0.055517     452000000.0
#
# [23052 rows x 11 columns]

# %% [markdown]
# ### Method 2

# %% [markdown]
# You can directly apply a function to every row in a column (or Series) with a special Pandas methods called `.apply()`.

# %%
film_df['gross_millions2'] = film_df['gross'].apply(make_millions)

# %%
film_df
# Out:
#        script_id        character  words gender   age    imdb_id  \
# 0            280            betty    311      f  35.0  tt0112579
# 1            280  carolyn johnson    873      f   NaN  tt0112579
# 2            280          eleanor    138      f   NaN  tt0112579
# 3            280  francesca johns   2251      f  46.0  tt0112579
# 4            280            madge    190      f  46.0  tt0112579
# ...          ...              ...    ...    ...   ...        ...
# 23047       9254          maurice   1107      m  71.0  tt0101414
# 23048       9254  monsieur d'arqu    114      m  58.0  tt0101414
# 23049       9254       mrs. potts    564      f  66.0  tt0101414
# 23050       9254         wardrobe    121      f  54.0  tt0101414
# 23051       9254       mrs. potts    564      f  66.0  tt0101414
#
#                                title  release_year  gross  \
# 0      The Bridges of Madison County          1995  142.0
# 1      The Bridges of Madison County          1995  142.0
# 2      The Bridges of Madison County          1995  142.0
# 3      The Bridges of Madison County          1995  142.0
# 4      The Bridges of Madison County          1995  142.0
# ...                              ...           ...    ...
# 23047           Beauty and the Beast          1991  452.0
# 23048           Beauty and the Beast          1991  452.0
# 23049           Beauty and the Beast          1991  452.0
# 23050           Beauty and the Beast          1991  452.0
# 23051           Beauty and the Beast          1991  452.0
#
#        proportion_of_dialogue  gross_millions  gross_millions2
# 0                    0.048639     142000000.0      142000000.0
# 1                    0.136534     142000000.0      142000000.0
# 2                    0.021583     142000000.0      142000000.0
# 3                    0.352049     142000000.0      142000000.0
# 4                    0.029715     142000000.0      142000000.0
# ...                       ...             ...              ...
# 23047                0.108967     452000000.0      452000000.0
# 23048                0.011222     452000000.0      452000000.0
# 23049                0.055517     452000000.0      452000000.0
# 23050                0.011911     452000000.0      452000000.0
# 23051                0.055517     452000000.0      452000000.0
#
# [23052 rows x 12 columns]

# %% [markdown]
# Let's transform the column `proportion_of_dialogue` into a percentage, e.g., .02 -> 2.

# %% [markdown]
# Make a Python function called `make_percent()` that will take in a number and then return that number mutlipled by 100.

# %%
# def ...

# %% [markdown]
# Make a new column "percentage_of_dialogue" by applying this function to the "proportion of dialogue" column.

# %%
# film_df['percentage_of_dialogue'] = ...

# %% [markdown]
# ## More Useful Methods

# %% [markdown]
# ### Make a Series into a DataFrame

# %% [markdown]
# Here's a Series:

# %%
film_df.groupby('title')['words'].sum()
# Out:
# title
# (500) Days of Summer          18500
# 10 Things I Hate About You    19680
# 12 Years a Slave              19628
# 12 and Holding                15968
# 127 Hours                      5145
#                               ...
# Zero Effect                   13927
# Zerophilia                    16686
# Zodiac                        14656
# eXistenZ                       9447
# xXx                            8285
# Name: words, Length: 1994, dtype: int64

# %% [markdown]
# You can make a Series object into a DataFrame object by using two square brackets instead of one.

# %%
film_df.groupby('title')[['words']].sum()
# Out:
#                             words
# title
# (500) Days of Summer        18500
# 10 Things I Hate About You  19680
# 12 Years a Slave            19628
# 12 and Holding              15968
# 127 Hours                    5145
# ...                           ...
# Zero Effect                 13927
# Zerophilia                  16686
# Zodiac                      14656
# eXistenZ                     9447
# xXx                          8285
#
# [1994 rows x 1 columns]

# %% [markdown]
# But perhaps the most useful method, especially after grouping by a category, is to use `.reset_index()`. The index is "reset" to ascending numbers, and the groupby category becomes a regular column.

# %%
film_df.groupby('title')[['words']].sum().reset_index()
# Out:
#                            title  words
# 0           (500) Days of Summer  18500
# 1     10 Things I Hate About You  19680
# 2               12 Years a Slave  19628
# 3                 12 and Holding  15968
# 4                      127 Hours   5145
# ...                          ...    ...
# 1989                 Zero Effect  13927
# 1990                  Zerophilia  16686
# 1991                      Zodiac  14656
# 1992                    eXistenZ   9447
# 1993                         xXx   8285
#
# [1994 rows x 2 columns]

# %% [markdown]
# ### Change Data Types

# %% [markdown]
# You can convert data types with `.astype()` ([documentation here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html)).

# %%
film_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23052 entries, 0 to 23051
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   script_id               23052 non-null  int64
#  1   character               23050 non-null  object
#  2   words                   23052 non-null  int64
#  3   gender                  23052 non-null  object
#  4   age                     18266 non-null  float64
#  5   imdb_id                 23052 non-null  object
#  6   title                   23052 non-null  object
#  7   release_year            23052 non-null  int64
#  8   gross                   19390 non-null  float64
#  9   proportion_of_dialogue  23052 non-null  float64
#  10  gross_millions          19390 non-null  float64
#  11  gross_millions2         19390 non-null  float64
#  12  percentage_of_dialogue  23052 non-null  object
# dtypes: float64(5), int64(3), object(5)
# memory usage: 2.3+ MB

# %%
film_df['script_id'].astype('str')
# Out:
# 0         280
# 1         280
# 2         280
# 3         280
# 4         280
#          ...
# 23047    9254
# 23048    9254
# 23049    9254
# 23050    9254
# 23051    9254
# Name: script_id, Length: 23052, dtype: object

# %% [markdown]
# Try to convert "age" to an integer and see what happens...

# %%
# film_df['age'].astype(int)

# %% [markdown]
# Pandas says that you cannot convert NaN values to integers. If we're ok with keeping the Nan values, we can simply choose to "ignore" the errors.

# %%
film_df['age'].astype(int, errors='ignore')
# Out:
# 0        35.0
# 1         NaN
# 2         NaN
# 3        46.0
# 4        46.0
#          ...
# 23047    71.0
# 23048    58.0
# 23049    66.0
# 23050    54.0
# 23051    66.0
# Name: age, Length: 23052, dtype: float64

# %% [markdown]
# Convert to a datetime data type

# %%
pd.to_datetime(film_df['release_year'], format='%Y')
# Out:
# 0       1995-01-01
# 1       1995-01-01
# 2       1995-01-01
# 3       1995-01-01
# 4       1995-01-01
#            ...
# 23047   1991-01-01
# 23048   1991-01-01
# 23049   1991-01-01
# 23050   1991-01-01
# 23051   1991-01-01
# Name: release_year, Length: 23052, dtype: datetime64[ns]

# %% [markdown]
# ### Binning

# %% [markdown]
# You can use `pd.cut()` to bin values ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html)).

# %%
pd.cut(film_df['age'], bins=[0, 25, 50, 75, 100], labels= ['0-25', '25-50', '50-75', '75-100'])
# Out:
# 0        25-50
# 1          NaN
# 2          NaN
# 3        25-50
# 4        25-50
#          ...
# 23047    50-75
# 23048    50-75
# 23049    50-75
# 23050    50-75
# 23051    50-75
# Name: age, Length: 23052, dtype: category
# Categories (4, object): ['0-25' < '25-50' < '50-75' < '75-100']

# %%
binned_age = pd.cut(film_df['age'], bins=[0, 25, 50, 75, 100], labels= ['0-25', '25-50', '50-75', '75-100'])

# %%
binned_age.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
film_df['age'].hist(bins=[0, 25, 50, 75, 100])
# Out:
# <AxesSubplot:>
